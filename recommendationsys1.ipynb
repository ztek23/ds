# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("movies_metadata.csv")
data.head()
# Out:
# C:\Users\zacha\AppData\Local\Temp\ipykernel_19948\2503762595.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("movies_metadata.csv")
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
data.describe()
# Out:
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000

# %%
# Convert vote_count and vote_average to numeric, forcing non-numeric values to NaN
data["vote_count"] = pd.to_numeric(data["vote_count"], errors="coerce")
data["vote_average"] = pd.to_numeric(data["vote_average"], errors="coerce")

# Drop rows with NaN values in vote_count or vote_average
data = data.dropna(subset=["vote_count", "vote_average"])

# %%
data["vote_count"] = data["vote_count"].astype(float)
data["vote_average"] = data["vote_average"].astype(float)

# %%
C = data["vote_average"].mean()
print(C)
# Out:
# 5.618207215134184

# %%
m = data["vote_count"].quantile(0.9)
print(m)
# Out:
# 160.0

# %%
#filter out all the qualified movies in to a new dataframe
q_movies = data.copy().loc[data["vote_count"] >= m]
print(q_movies.shape)
# Out:
# (4555, 24)

# %%
# def weighted_rating(x, m = m, C = "C"):
#     v = x["vote_count"]
#     R = x["vote_average"]

#     return (v/(v+m)*R) + (m/(m+v)*C)
# q_movies["score"] = q_movies.apply(weighted_rating, axis = 1)
# q_movies = q_movies.sort_values("score", ascending = False)

# printing the top 20 movies 
print(q_movies[["title", "vote_count", "vote_average"]].head(20))
# Out:
#                              title  vote_count  vote_average
# 0                        Toy Story      5415.0           7.7
# 1                          Jumanji      2413.0           6.9
# 4      Father of the Bride Part II       173.0           5.7
# 5                             Heat      1886.0           7.7
# 8                     Sudden Death       174.0           5.5
# 9                        GoldenEye      1194.0           6.6
# 10          The American President       199.0           6.5
# 11     Dracula: Dead and Loving It       210.0           5.7
# 12                           Balto       423.0           7.1
# 15                          Casino      1343.0           7.8
# 16           Sense and Sensibility       364.0           7.2
# 17                      Four Rooms       539.0           6.5
# 18  Ace Ventura: When Nature Calls      1128.0           6.1
# 19                     Money Train       224.0           5.4
# ...
